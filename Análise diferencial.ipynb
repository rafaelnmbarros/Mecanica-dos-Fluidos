# %% [markdown]
# ### Problema 7-18 do livro Mecânica dos Fluidos (R. C. Hibbeler)

# %%
import sympy as sp
from sympy import *
sp.init_printing(use_latex="mathjax")
from sympy.plotting import plot
from sympy import latex


#Entrada de dados
x, y, t, C, f_x, d_f_x = sp.symbols("x y t C f(x) f'(x)")
u=2*x**2
v=-4*x*y+x**2
valor_x=3
valor_y=1
xmin=0
xmax=8
ymin=0
ymax=8

psi=sp.integrate(u,y)+f_x               #integração em relação a y
d_f_x=-(v+sp.diff(psi,x))               #derivada da função f(x)
definicao_f_x = sp.integrate(d_f_x,x)+C #integração em relação a x
psi=psi.subs(f_x,definicao_f_x)         #substituição da função f(x)
psi=psi.subs(C,0)                       #utilizando C = 0
valor_psi=psi.subs(x,valor_x).subs(y,valor_y)
Eq_y=sp.solveset(sp.Eq(psi,valor_psi),y).args[0]

#Exibição dos resultados
p1=plot(Eq_y, label='Linha de trajetória', xlabel='x(m)', ylabel = 'y (m)', show=False, legend=True, line_color='blue', xlim=(xmin, xmax), ylim=(ymin, ymax))
p1.show()

# %%
import sympy as sp
from sympy import *
sp.init_printing(use_latex="mathjax")
from sympy.plotting import plot
from sympy import latex


#Entrada de dados
x, y, t, C, f_x, d_f_x = sp.symbols("x y t C f(x) f'(x)")
psi_xy=y**2-x
valor_psi_1=0
valor_psi_2=2
valor_psi_3=4
valor_y=1
xmin=-8
xmax=8
ymin=-4
ymax=4

Eq_y_1=sp.solveset(sp.Eq(psi_xy,valor_psi_1),y).args[0]
Eq_y_2=sp.solveset(sp.Eq(psi_xy,valor_psi_2),y).args[0]
Eq_y_3=sp.solveset(sp.Eq(psi_xy,valor_psi_3),y).args[0]
u=sp.diff(psi_xy,y)
v=-sp.diff(psi_xy,x)
valor_x=sp.solveset(Eq_y_2.subs(y,valor_y),x).args[0]
valor_u=u.subs(x,valor_x).subs(y,valor_y)
valor_v=v.subs(x,valor_x).subs(y,valor_y)
valor_V=sp.sqrt(valor_u**2+valor_v**2)

#Exibição dos resultados
print("Velocidade no ponto x = %f m" % float(valor_x), "e y = %f m:" % float(valor_y))
print('V = %f m/s' % float(valor_V))
p1=plot(Eq_y_1, label='$\psi_{1}$', xlabel='x(m)', ylabel = 'y (m)', show=False, legend=True, line_color='blue', xlim=(xmin, xmax), ylim=(ymin, ymax))
p2=plot(-Eq_y_1, label='$\psi_{1}$', xlabel='x(m)', ylabel = 'y (m)', show=False, legend=False, line_color='blue', xlim=(xmin, xmax), ylim=(ymin, ymax))
p3=plot(Eq_y_2, label='$\psi_{2}$', xlabel='x(m)', ylabel = 'y (m)', show=False, legend=True, line_color='red', xlim=(xmin, xmax), ylim=(ymin, ymax))
p4=plot(-Eq_y_2, label='$\psi_{2}$', xlabel='x(m)', ylabel = 'y (m)', show=False, legend=False, line_color='red', xlim=(xmin, xmax), ylim=(ymin, ymax))
p5=plot(Eq_y_3, label='$\psi_{3}$', xlabel='x(m)', ylabel = 'y (m)', show=False, legend=True, line_color='green', xlim=(xmin, xmax), ylim=(ymin, ymax))
p6=plot(-Eq_y_3, label='$\psi_{3}$', xlabel='x(m)', ylabel = 'y (m)', show=False, legend=False, line_color='green', xlim=(xmin, xmax), ylim=(ymin, ymax))
p1.append(p2[0])
p1.append(p3[0])
p1.append(p4[0])
p1.append(p5[0])
p1.append(p6[0])
p1.show()
# Out:
# Velocidade no ponto x = -2.000000 m e y = 1.000000 m:
# V = 2.236068 m/s

# %%
float(V)
# Out:
# 2.23606797749979
